# %% [markdown]
# <a href="https://colab.research.google.com/github/tarsislimadev/python-examples/blob/main/matplotlib-openbb-historicals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install libraries

# %%
# !pip install openbb requests aiosqlite fastapi

# %% [markdown]
# # Import libraries

# %%
from openbb import obb

# %% [markdown]
# # Get historical prices

# %%
output = obb.equity.price.historical("MSFT")
# Out:
# OBBject[T]
#
# id: 0697614b-d577-7da3-8000-520a3200e33a
# results: [{'date': datetime.date(2025, 1, 27), 'open': 424.010009765625, 'high': 43...
# provider: yfinance
# warnings: None
# chart: None
# extra: {'metadata': {'arguments': {'provider_choices': {'provider': 'yfinance'}, 's...

# %% [markdown]
# # Get dataframe

# %%
df = output.to_dataframe()
# Out:
#                   open
# date
# 2025-01-27  424.010010
# 2025-01-28  434.600006
# 2025-01-29  446.690002
# 2025-01-30  418.769989
# 2025-01-31  418.980011
# ...                ...
# 2026-01-16  457.829987
# 2026-01-20  451.220001
# 2026-01-21  452.600006
# 2026-01-22  447.619995
# 2026-01-23  451.869995
#
# [250 rows x 1 columns]

# %% [markdown]
# # Show data

# %%
import matplotlib.pyplot as plt

kline_open_time = df.index
open_price = df['open']

plt.figure(figsize=(9, 3))
plt.plot(kline_open_time, open_price)
plt.show()
