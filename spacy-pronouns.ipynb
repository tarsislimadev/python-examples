# %%
# !pip install spacy

# %%
import spacy
spacy.__version__

# %%
# !python -m spacy download pt_core_news_sm

# %%
import pt_core_news_sm

# %%
nlp = spacy.load('pt_core_news_sm')

# %%
document = nlp('Mark Zuckerberg criou o Facebook')
document

# %%
words = []
for token in document:
    if token.pos_ == 'PROPN':
      words.append('XXXX')
    else:
      words.append(token.text)

# %%
' '.join(words)
