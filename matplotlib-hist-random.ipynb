# %%
# !pip install numpy matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
media=50
desvio=10
n=1000

# %%
valores=np.random.normal(loc=media, scale=desvio, size=n)
valores

# %%
plt.hist(valores)
plt.show()
