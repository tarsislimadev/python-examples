# %% [markdown]
# # Dados abertos (Pensionistas UFU janeiro/2022)
#
# URL: https://dados.ufu.br/recurso/pensionistas-janeiro2022#{}

# %%
# !python -m pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('./data.utf8.csv', sep=';')
df = df.replace(to_replace=r"R[$] ?", value="", regex=True)

# %%
df = df[df['DescricaoDespesa'] == 'Vencimentos e Vantagem Fixas']
df[' Valor '] = pd.to_numeric(df[' Valor '], errors='coerce')
df.head(20)
