# %% [markdown]
# # Rio Claro SP in geopandas

# %% [markdown]
# https://github.com/ipeaGIT/geobr

# %% [markdown]
# # Install geopandas

# %%
# !pip install geobr geopandas

# %% [markdown]
# # Import libraries

# %%
import matplotlib.pyplot as plt
import geobr
import geopandas as gpd

# %% [markdown]
# # Load data

# %%
muni = geobr.read_municipality(code_muni='SP', year=2024)
muni.head()
# Out:
#    code_muni         name_muni  code_state abbrev_state name_state  \
# 0  3500105.0        Adamantina        35.0           SP  São Paulo
# 1  3500204.0            Adolfo        35.0           SP  São Paulo
# 2  3500303.0             Aguaí        35.0           SP  São Paulo
# 3  3500402.0    Águas da Prata        35.0           SP  São Paulo
# 4  3500501.0  Águas de Lindóia        35.0           SP  São Paulo
#
#    code_region name_region                                           geometry
# 0          3.0     Sudeste  MULTIPOLYGON (((-51.05196 -21.70964, -51.04007...
# 1          3.0     Sudeste  MULTIPOLYGON (((-49.61234 -21.2564, -49.60982 ...
# 2          3.0     Sudeste  MULTIPOLYGON (((-47.01277 -22.00589, -47.01219...
# 3          3.0     Sudeste  MULTIPOLYGON (((-46.71852 -21.95893, -46.71681...
# 4          3.0     Sudeste  MULTIPOLYGON (((-46.61723 -22.51122, -46.61212...

# %% [markdown]
# # Show and save state's image

# %%
fig, ax = plt.subplots(figsize=(9, 16))
muni.plot(figsize=(9, 16), ax=ax)
ax.axis('off')
fig.savefig('sao_paulo.png')

# %% [markdown]
# # Show and save city's image

# %%
fig_rc, ax_rc = plt.subplots(figsize=(9, 16))
muni_rc = muni[muni.name_muni == 'Rio Claro']
muni_rc.plot(figsize=(9, 16), ax=ax_rc)
ax_rc.axis('off')
fig_rc.savefig('rio_claro.png')
